# %%
from PIL import Image
pil_im = Image.open('empire.jpg')

# %%
pil_im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=383x640 at 0x1091C9BA8>

# %%
pil_im = Image.open('empire.jpg').convert('L')
pil_im
# Out:
# <PIL.Image.Image image mode=L size=383x640 at 0x1091C9E48>

# %%
pil_thumb = Image.open('empire.jpg')
pil_thumb.thumbnail((128,128))
pil_thumb
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=76x128 at 0x1091D7C50>

# %%
box = (100,100,400,400)
region = pil_im.crop(box)
region
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x10964C0B8>

# %%
pil_resize = Image.open('empire.jpg')
pil_resize = pil_resize.resize((128,128))
pil_resize
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x1091D7F60>

# %%
pil_rotate = Image.open('empire.jpg')
pil_rotate = pil_rotate.rotate(45)
pil_rotate
# Out:
# <PIL.Image.Image image mode=RGB size=383x640 at 0x10964C2B0>
